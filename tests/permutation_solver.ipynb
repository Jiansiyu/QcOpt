# %%
from quantumc_optimizer.quantumCircuit import *
from quantumc_optimizer import permutationsolver

# %%
quantc = ibmq_belem()
quantc.draw()

# %%
solver = permutationsolver.PermutationSolver(max_n=4,qcircuit=quantc)
solver.solve([x for x in range(5)])
# Out:
# [[[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [2, 1, 0, 3, 4],
#   [2, 0, 1, 3, 4]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [2, 1, 0, 3, 4],
#   [2, 3, 0, 1, 4]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [2, 1, 0, 3, 4],
#   [2, 1, 0, 4, 3]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 3, 0, 2, 4],
#   [3, 1, 0, 2, 4]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 3, 0, 2, 4],
#   [1, 0, 3, 2, 4]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 3, 0, 2, 4],
#   [1, 3, 0, 4, 2]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 2, 0, 4, 3],
#   [2, 1, 0, 4, 3]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 2, 0, 4, 3],
#   [1, 0, 2, 4, 3]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
#   [1, 2, 0, 3, 4],
#   [1, 2, 0, 4, 3],
#   [1, 4, 0, 2, 3]],
#  [[0, 1, 2, 3, 4],
#   [1, 0, 2, 3, 4],
# ...
